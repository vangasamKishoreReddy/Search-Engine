# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
# Read the code below and write your observation in the next cell

conn = sqlite3.connect(r"C:\Users\vkr20\Desktop\All Projects\Internship\Datsets of this\eng_subtitles_database.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
# Out:
# [('zipfiles',)]

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# num
# name
# content

# %%
df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...

# %%
import zipfile
import io

count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    # print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])
    
    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
df
# Out:
#            num                                               name  \
# 0      9180533                         the.message.(1976).eng.1cd
# 1      9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2      9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3      9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4      9180600                              broker.(2022).eng.1cd
# ...        ...                                                ...
# 82493  9521935                   the.prophets.game.(2000).eng.1cd
# 82494  9521937                         west.beirut.(1998).eng.1cd
# 82495  9521938         frankenstein.the.true.story.(1973).eng.1cd
# 82496  9521940         frankenstein.the.true.story.(1973).eng.1cd
# 82497  9521941              zombie.island.massacre.(1984).eng.1cd
#
#                                                  content
# 0      b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1      b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2      b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3      b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4      b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
# ...                                                  ...
# 82493  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xb8\xa6\x...
# 82494  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x13\x97\x...
# 82495  b'PK\x03\x04\x14\x00\x00\x00\x08\x00$\x97\x9aV...
# 82496  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x00\x97\x...
# 82497  b'PK\x03\x04\x14\x00\x00\x00\x08\x00,\x97\x9aV...
#
# [82498 rows x 3 columns]

# %%
from tqdm import tqdm
tqdm.pandas()

df['file_content'] = df['content'].progress_apply(decode_method)

#Display the First Few Rows of the DF
df.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 82498/82498 [01:19<00:00, 1036.24it/s]
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %%
df_sample= df.sample(frac=0.3)

import re
# Regular expression pattern to remove timestamps
timestamp_pattern = r'\d{2}:\d{2}:\d{2},\d{3} --> \d{2}:\d{2}:\d{2},\d{3}'
# Regular expression pattern to remove unwanted characters like '\r', '\n', 'ï»¿'
unwanted_pattern = r'[\r\nï»¿]'

# Function to clean the content
def clean_content(text):
    text = re.sub(timestamp_pattern, '', text)  # Remove timestamps
    text = re.sub(unwanted_pattern, '', text)    # Remove unwanted characters
    text = re.sub(r'<.*?>', '', text)            # Remove HTML tags
    text = text.strip()                          # Strip leading/trailing whitespace
    text = re.sub(r'^\d+', '', text.strip())     # Remove leading '1'
    return text.strip()

# Apply the cleaning function to the 'content' column
df_sample['cleaned_content'] = df_sample['file_content'].progress_apply(clean_content)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 24749/24749 [02:22<00:00, 173.22it/s]

# %%
df_sample= df.sample(frac=0.1)

import re
# Regular expression pattern to remove timestamps
timestamp_pattern = r'\d{2}:\d{2}:\d{2},\d{3} --> \d{2}:\d{2}:\d{2},\d{3}'
# Regular expression pattern to remove unwanted characters like '\r', '\n', 'ï»¿'
unwanted_pattern = r'[\r\nï»¿]'

# Function to clean the content
def clean_content(text):
    text = re.sub(timestamp_pattern, '', text)  # Remove timestamps
    text = re.sub(unwanted_pattern, '', text)    # Remove unwanted characters
    text = re.sub(r'<.*?>', '', text)            # Remove HTML tags
    text = text.strip()                          # Strip leading/trailing whitespace
    text = re.sub(r'^\d+', '', text.strip())     # Remove leading '1'
    return text.strip()

# Apply the cleaning function to the 'content' column
df_sample['cleaned_content'] = df_sample['file_content'].progress_apply(clean_content)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 8250/8250 [00:46<00:00, 176.87it/s]

# %%
## step3: Data Preprocessing on train data
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
df_sample
# Out:
#            num                                               name  \
# 13792  9238535                the.boyfriend.school.(1990).eng.1cd
# 27664  9291572        younger.s07.e08.the.baroness.(2021).eng.1cd
# 72395  9478531  would.i.lie.to.you.s16.e08.episode.16.8.(2022)...
# 17047  9250225  desperate.housewives.s01.e05.come.in.stranger....
# 49377  9388517  the.king.of.queens.s02.e15.frozen.pop.(2000).e...
# ...        ...                                                ...
# 28868  9296396       sistas.s05.e02.my.boyfriends.back.().eng.1cd
# 40343  9346216  the.sopranos.s05.e04.all.happy.families.(2004)...
# 43354  9358241  voyages.of.discovery.s01.e01.circumnavigation....
# 59525  9430130       the.flintstones.jogging.fever.(1981).eng.1cd
# 6026   9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
#
#                                                  content  \
# 13792  b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 27664  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x16\xa5\x...
# 72395  b'PK\x03\x04\x14\x00\x00\x00\x08\x00=b\x9aVs\x...
# 17047  b'PK\x03\x04\x14\x00\x00\x00\x08\x00T\x9a\x99V...
# 49377  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x10\x1e\x...
# ...                                                  ...
# 28868  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1b\xa7\x...
# 40343  b'PK\x03\x04\x14\x00\x00\x00\x08\x00:\xbd\x99V...
# 43354  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xa0\x19\x...
# 59525  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xe19\x9aV...
# 6026   b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
#
#                                             file_content  \
# 13792  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 27664  ï»¿1\r\n00:00:04,171 --> 00:00:05,503\r\n- Tha...
# 72395  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
# 17047  ï»¿1\r\n00:00:00,901 --> 00:00:02,784\r\n<i>Pr...
# 49377  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# ...                                                  ...
# 28868  ï»¿1\r\n00:00:01,234 --> 00:00:03,370\r\n<font...
# 40343  1\r\n00:00:08,258 --> 00:00:09,843\r\n(Music)\...
# 43354  ï»¿1\r\n00:00:12,600 --> 00:00:18,920\r\n500 y...
# 59525  ï»¿1\r\n00:00:01,101 --> 00:00:05,305\r\n[sere...
# 6026   ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
#
#                                          cleaned_content
# 13792  Advertise your product or brand herecontact ww...
# 27664  - Thank you.- I thought you guys2were perfect ...
# 72395  api.OpenSubtitles.org is deprecated, pleaseimp...
# 17047  Previously onDesperate Housewives...2The boys ...
# 49377  Support us and become VIP member to remove all...
# ...                                                  ...
# 28868  {\an1}I need a lawyer.I need to talk to somebo...
# 40343  (Music)2-== [ www.OpenSubtitles.com ] ==-3That...
# 43354  years ago, an unrecognizable shiparrived in th...
# 59525  [serene music]2[alarm clocks ringing]3[upbeat ...
# 6026   âª Well, we're movin' on upâª Movin' on up2â...
#
# [8250 rows x 5 columns]

# %%
def preprocess(raw_text):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", raw_text)

    #change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens =nltk.word_tokenize(sentence)

    #Lemmatize
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    #remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in lemmatized_tokens if word.lower() not in stop_words]

    #Join and return
    return " ".join(filtered_tokens)

# %%
df_sample['cleaned_content'] = df_sample['cleaned_content'].progress_apply(lambda x:  preprocess(x))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 8250/8250 [12:44<00:00, 10.79it/s]

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vkr20\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df_sample
# Out:
#            num                                               name  \
# 13792  9238535                the.boyfriend.school.(1990).eng.1cd
# 27664  9291572        younger.s07.e08.the.baroness.(2021).eng.1cd
# 72395  9478531  would.i.lie.to.you.s16.e08.episode.16.8.(2022)...
# 17047  9250225  desperate.housewives.s01.e05.come.in.stranger....
# 49377  9388517  the.king.of.queens.s02.e15.frozen.pop.(2000).e...
# ...        ...                                                ...
# 28868  9296396       sistas.s05.e02.my.boyfriends.back.().eng.1cd
# 40343  9346216  the.sopranos.s05.e04.all.happy.families.(2004)...
# 43354  9358241  voyages.of.discovery.s01.e01.circumnavigation....
# 59525  9430130       the.flintstones.jogging.fever.(1981).eng.1cd
# 6026   9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
#
#                                                  content  \
# 13792  b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 27664  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x16\xa5\x...
# 72395  b'PK\x03\x04\x14\x00\x00\x00\x08\x00=b\x9aVs\x...
# 17047  b'PK\x03\x04\x14\x00\x00\x00\x08\x00T\x9a\x99V...
# 49377  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x10\x1e\x...
# ...                                                  ...
# 28868  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1b\xa7\x...
# 40343  b'PK\x03\x04\x14\x00\x00\x00\x08\x00:\xbd\x99V...
# 43354  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xa0\x19\x...
# 59525  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xe19\x9aV...
# 6026   b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
#
#                                             file_content  \
# 13792  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 27664  ï»¿1\r\n00:00:04,171 --> 00:00:05,503\r\n- Tha...
# 72395  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
# 17047  ï»¿1\r\n00:00:00,901 --> 00:00:02,784\r\n<i>Pr...
# 49377  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# ...                                                  ...
# 28868  ï»¿1\r\n00:00:01,234 --> 00:00:03,370\r\n<font...
# 40343  1\r\n00:00:08,258 --> 00:00:09,843\r\n(Music)\...
# 43354  ï»¿1\r\n00:00:12,600 --> 00:00:18,920\r\n500 y...
# 59525  ï»¿1\r\n00:00:01,101 --> 00:00:05,305\r\n[sere...
# 6026   ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
#
#                                          cleaned_content
# 13792  advertise product brand herecontact www opensu...
# 27664  thank thought guy perfect eachother happened w...
# 72395  api opensubtitles org deprecated pleaseimpleme...
# 17047  previously ondesperate housewife boy classbeca...
# 49377  support u become vip member remove ad www open...
# ...                                                  ...
# 28868  need lawyer need talk somebody look lady got i...
# 40343  music www opensubtitles com funny poked eye we...
# 43354  year ago unrecognizable shiparrived port sevil...
# 59525  serene music alarm clock ringing upbeat music ...
# 6026   well movin movin east side movin deluxe apartm...
#
# [8250 rows x 5 columns]

# %%
def chunk_document(corpous, id_col, chunk_size=300):
    data = []

    for doc,id  in zip(corpous, id_col):
        
        words = doc.split()
        for i in range(0, len(words), chunk_size):
            chunk = ' '.join(words[i:i + chunk_size])


            data.append((id,chunk))

    df = pd.DataFrame(data)

    return df

# %%
df_sample
# Out:
#            num                                               name  \
# 13792  9238535                the.boyfriend.school.(1990).eng.1cd
# 27664  9291572        younger.s07.e08.the.baroness.(2021).eng.1cd
# 72395  9478531  would.i.lie.to.you.s16.e08.episode.16.8.(2022)...
# 17047  9250225  desperate.housewives.s01.e05.come.in.stranger....
# 49377  9388517  the.king.of.queens.s02.e15.frozen.pop.(2000).e...
# ...        ...                                                ...
# 28868  9296396       sistas.s05.e02.my.boyfriends.back.().eng.1cd
# 40343  9346216  the.sopranos.s05.e04.all.happy.families.(2004)...
# 43354  9358241  voyages.of.discovery.s01.e01.circumnavigation....
# 59525  9430130       the.flintstones.jogging.fever.(1981).eng.1cd
# 6026   9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
#
#                                                  content  \
# 13792  b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 27664  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x16\xa5\x...
# 72395  b'PK\x03\x04\x14\x00\x00\x00\x08\x00=b\x9aVs\x...
# 17047  b'PK\x03\x04\x14\x00\x00\x00\x08\x00T\x9a\x99V...
# 49377  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x10\x1e\x...
# ...                                                  ...
# 28868  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1b\xa7\x...
# 40343  b'PK\x03\x04\x14\x00\x00\x00\x08\x00:\xbd\x99V...
# 43354  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xa0\x19\x...
# 59525  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xe19\x9aV...
# 6026   b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
#
#                                             file_content  \
# 13792  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 27664  ï»¿1\r\n00:00:04,171 --> 00:00:05,503\r\n- Tha...
# 72395  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
# 17047  ï»¿1\r\n00:00:00,901 --> 00:00:02,784\r\n<i>Pr...
# 49377  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# ...                                                  ...
# 28868  ï»¿1\r\n00:00:01,234 --> 00:00:03,370\r\n<font...
# 40343  1\r\n00:00:08,258 --> 00:00:09,843\r\n(Music)\...
# 43354  ï»¿1\r\n00:00:12,600 --> 00:00:18,920\r\n500 y...
# 59525  ï»¿1\r\n00:00:01,101 --> 00:00:05,305\r\n[sere...
# 6026   ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
#
#                                          cleaned_content
# 13792  advertise product brand herecontact www opensu...
# 27664  thank thought guy perfect eachother happened w...
# 72395  api opensubtitles org deprecated pleaseimpleme...
# 17047  previously ondesperate housewife boy classbeca...
# 49377  support u become vip member remove ad www open...
# ...                                                  ...
# 28868  need lawyer need talk somebody look lady got i...
# 40343  music www opensubtitles com funny poked eye we...
# 43354  year ago unrecognizable shiparrived port sevil...
# 59525  serene music alarm clock ringing upbeat music ...
# 6026   well movin movin east side movin deluxe apartm...
#
# [8250 rows x 5 columns]

# %%
chuncked_df = chunk_document(df_sample.cleaned_content,df_sample.num)

# %%
chuncked_df
# Out:
#              0                                                  1
# 0      9238535  advertise product brand herecontact www opensu...
# 1      9238535  oh please mean review mail get well card diary...
# 2      9238535  take quiet moment shall need see mr renault ri...
# 3      9238535  laugh mitchell wow never knew lizzie looked th...
# 4      9238535  skewed little bittoo heavily towards ginger mm...
# ...        ...                                                ...
# 76031  9207441  well movin movin east side movin deluxe apartm...
# 76032  9207441  sure havea special dessert two oh ice cream ch...
# 76033  9207441  yeah becausenobody else see u right uh gentlem...
# 76034  9207441  startedon speech ah hey fifthof scotch come oh...
# 76035  9207441  three george doe itlook like gettingthe hell g...
#
# [76036 rows x 2 columns]

# %%
chuncked_df.columns =['num','file_content_chunks']

# %%
chuncked_df
# Out:
#            num                                file_content_chunks
# 0      9238535  advertise product brand herecontact www opensu...
# 1      9238535  oh please mean review mail get well card diary...
# 2      9238535  take quiet moment shall need see mr renault ri...
# 3      9238535  laugh mitchell wow never knew lizzie looked th...
# 4      9238535  skewed little bittoo heavily towards ginger mm...
# ...        ...                                                ...
# 76031  9207441  well movin movin east side movin deluxe apartm...
# 76032  9207441  sure havea special dessert two oh ice cream ch...
# 76033  9207441  yeah becausenobody else see u right uh gentlem...
# 76034  9207441  startedon speech ah hey fifthof scotch come oh...
# 76035  9207441  three george doe itlook like gettingthe hell g...
#
# [76036 rows x 2 columns]

# %%
merged_df = chuncked_df.merge(df_sample,left_on="num",right_on="num",how="left")

# %%
merged_df
# Out:
#            num                                file_content_chunks  \
# 0      9238535  advertise product brand herecontact www opensu...
# 1      9238535  oh please mean review mail get well card diary...
# 2      9238535  take quiet moment shall need see mr renault ri...
# 3      9238535  laugh mitchell wow never knew lizzie looked th...
# 4      9238535  skewed little bittoo heavily towards ginger mm...
# ...        ...                                                ...
# 76031  9207441  well movin movin east side movin deluxe apartm...
# 76032  9207441  sure havea special dessert two oh ice cream ch...
# 76033  9207441  yeah becausenobody else see u right uh gentlem...
# 76034  9207441  startedon speech ah hey fifthof scotch come oh...
# 76035  9207441  three george doe itlook like gettingthe hell g...
#
#                                                     name  \
# 0                    the.boyfriend.school.(1990).eng.1cd
# 1                    the.boyfriend.school.(1990).eng.1cd
# 2                    the.boyfriend.school.(1990).eng.1cd
# 3                    the.boyfriend.school.(1990).eng.1cd
# 4                    the.boyfriend.school.(1990).eng.1cd
# ...                                                  ...
# 76031  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76032  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76033  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76034  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76035  the.jeffersons.s06.e02.a.short.story.(1979).en...
#
#                                                  content  \
# 0      b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 1      b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 2      b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 3      b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# 4      b'PK\x03\x04\x14\x00\x00\x00\x08\x00g\x97\x99V...
# ...                                                  ...
# 76031  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
# 76032  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
# 76033  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
# 76034  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
# 76035  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x8d\x...
#
#                                             file_content  \
# 0      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 1      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 2      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 3      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 4      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# ...                                                  ...
# 76031  ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
# 76032  ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
# 76033  ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
# 76034  ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
# 76035  ï»¿1\r\n00:00:02,203 --> 00:00:04,348\r\n<i>â...
#
#                                          cleaned_content
# 0      advertise product brand herecontact www opensu...
# 1      advertise product brand herecontact www opensu...
# 2      advertise product brand herecontact www opensu...
# 3      advertise product brand herecontact www opensu...
# 4      advertise product brand herecontact www opensu...
# ...                                                  ...
# 76031  well movin movin east side movin deluxe apartm...
# 76032  well movin movin east side movin deluxe apartm...
# 76033  well movin movin east side movin deluxe apartm...
# 76034  well movin movin east side movin deluxe apartm...
# 76035  well movin movin east side movin deluxe apartm...
#
# [76036 rows x 6 columns]

# %%
merged_df = merged_df[['num','name', 'file_content_chunks']]

# %%
merged_df
# Out:
#            num                                               name  \
# 0      9238535                the.boyfriend.school.(1990).eng.1cd
# 1      9238535                the.boyfriend.school.(1990).eng.1cd
# 2      9238535                the.boyfriend.school.(1990).eng.1cd
# 3      9238535                the.boyfriend.school.(1990).eng.1cd
# 4      9238535                the.boyfriend.school.(1990).eng.1cd
# ...        ...                                                ...
# 76031  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76032  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76033  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76034  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76035  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
#
#                                      file_content_chunks
# 0      advertise product brand herecontact www opensu...
# 1      oh please mean review mail get well card diary...
# 2      take quiet moment shall need see mr renault ri...
# 3      laugh mitchell wow never knew lizzie looked th...
# 4      skewed little bittoo heavily towards ginger mm...
# ...                                                  ...
# 76031  well movin movin east side movin deluxe apartm...
# 76032  sure havea special dessert two oh ice cream ch...
# 76033  yeah becausenobody else see u right uh gentlem...
# 76034  startedon speech ah hey fifthof scotch come oh...
# 76035  three george doe itlook like gettingthe hell g...
#
# [76036 rows x 3 columns]

# %%
for id, chunk in enumerate(merged_df):
    print(chunk)
# Out:
# num
# name
# file_content_chunks

# %%
#!pip install sentence_transformers

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Obtaining dependency information for chromadb from https://files.pythonhosted.org/packages/cc/63/b7d76109331318423f9cfb89bd89c99e19f5d0b47a5105439a629224d297/chromadb-0.4.24-py3-none-any.whl.metadata
#   Downloading chromadb-0.4.24-py3-none-any.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Obtaining dependency information for build>=1.0.3 from https://files.pythonhosted.org/packages/e2/03/f3c8ba0a6b6e30d7d18c40faab90807c9bb5e9a1e3b2fe2008af624a9c97/build-1.2.1-py3-none-any.whl.metadata
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests>=2.28 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (1.10.12)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Obtaining dependency information for chroma-hnswlib==0.7.3 from https://files.pythonhosted.org/packages/d2/32/a91850c7aa8a34f61838913155103808fe90da6f1ea4302731b59e9ba6f2/chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Obtaining dependency information for fastapi>=0.95.2 from https://files.pythonhosted.org/packages/ad/0f/feb7fd8957714498fc4a6be7f13408869619f868f418698a2d934afa82a7/fastapi-0.110.2-py3-none-any.whl.metadata
#   Downloading fastapi-0.110.2-py3-none-any.whl.metadata (24 kB)
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Obtaining dependency information for uvicorn[standard]>=0.18.3 from https://files.pythonhosted.org/packages/73/f5/cbb16fcbe277c1e0b8b3ddd188f2df0e0947f545c49119b589643632d156/uvicorn-0.29.0-py3-none-any.whl.metadata
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (1.26.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Obtaining dependency information for posthog>=2.4.0 from https://files.pythonhosted.org/packages/6c/5f/24cb22118db0e11703b6b80ef9f982eadde21eb585c3a769719e48dce893/posthog-3.5.0-py2.py3-none-any.whl.metadata
#   Downloading posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (4.11.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Obtaining dependency information for pulsar-client>=3.1.0 from https://files.pythonhosted.org/packages/fb/62/ed1da1ef72c95ba6a830e43995550ed0a1d26c223fb4b036ac6cd028c2ed/pulsar_client-3.5.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pulsar_client-3.5.0-cp311-cp311-win_amd64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Obtaining dependency information for onnxruntime>=1.14.1 from https://files.pythonhosted.org/packages/ea/ef/202d3fb284c5936f8aa6d87021963e8e8f776834aa18e8f440c268827639/onnxruntime-1.17.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading onnxruntime-1.17.3-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Obtaining dependency information for opentelemetry-api>=1.2.0 from https://files.pythonhosted.org/packages/81/30/603d64b33b1203638cf4fae49095bc9851fe09c6ad6d88dd10d7e6a9f999/opentelemetry_api-1.24.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.24.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-grpc>=1.2.0 from https://files.pythonhosted.org/packages/b0/14/cdfe43225303e621d9c329001dd4f922f249ec62b11a0729dbbb2eab14c7/opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Obtaining dependency information for opentelemetry-instrumentation-fastapi>=0.41b0 from https://files.pythonhosted.org/packages/c4/8e/6789b96a86f3f1f81dbfb381a5b6c83309c98bda8f072194735d58c2d0ec/opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Obtaining dependency information for opentelemetry-sdk>=1.2.0 from https://files.pythonhosted.org/packages/f2/de/13693237295f4b90f831feaac2481d0b467605ca307b964d6cb8b5a39da2/opentelemetry_sdk-1.24.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ---------------------------------------- 67.3/67.3 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/75/06/4df55e1b7b112d183f65db9503bff189e97179b256e1ea450a3c365241e0/importlib_resources-6.4.0-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (1.62.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Obtaining dependency information for bcrypt>=4.0.1 from https://files.pythonhosted.org/packages/53/5b/73803e5bf877e07739deaeecb2e356f4cc9ae3b766558959a898f7a993e0/bcrypt-4.1.2-cp39-abi3-win_amd64.whl.metadata
#   Downloading bcrypt-4.1.2-cp39-abi3-win_amd64.whl.metadata (9.8 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Obtaining dependency information for typer>=0.9.0 from https://files.pythonhosted.org/packages/20/b5/11cf2e34fbb11b937e006286ab5b8cfd334fde1c8fa4dd7f491226931180/typer-0.12.3-py3-none-any.whl.metadata
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Obtaining dependency information for kubernetes>=28.1.0 from https://files.pythonhosted.org/packages/6f/34/164e57fec8a9693d7e6ae2d1a345482020ea9e9b32eab95a90bb3eaea83d/kubernetes-29.0.0-py2.py3-none-any.whl.metadata
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Obtaining dependency information for tenacity>=8.2.3 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Obtaining dependency information for mmh3>=4.0.1 from https://files.pythonhosted.org/packages/d1/b0/500ef56c29b276d796bfdb47c16d34fa18a68945e4d730a6fa7d483583ed/mmh3-4.1.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading mmh3-4.1.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Obtaining dependency information for orjson>=3.9.12 from https://files.pythonhosted.org/packages/28/f2/62bdd14f712fbc36afb3e3885abf88b6804324d8ad074f9431adb7d702ab/orjson-3.10.1-cp311-none-win_amd64.whl.metadata
#   Downloading orjson-3.10.1-cp311-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      ---------------------------------------- 50.9/50.9 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=19.1 in c:\users\vkr20\program\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (23.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Obtaining dependency information for pyproject_hooks from https://files.pythonhosted.org/packages/d5/ea/9ae603de7fbb3df820b23a70f6aff92bf8c7770043254ad8d2dc9d6bcba4/pyproject_hooks-1.0.0-py3-none-any.whl.metadata
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\vkr20\program\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Obtaining dependency information for starlette<0.38.0,>=0.37.2 from https://files.pythonhosted.org/packages/fd/18/31fa32ed6c68ba66220204ef0be798c349d0a20c1901f9d4a794e08c76d8/starlette-0.37.2-py3-none-any.whl.metadata
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\vkr20\program\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2023.11.17)
# Requirement already satisfied: six>=1.9.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\vkr20\program\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for google-auth>=1.0.1 from https://files.pythonhosted.org/packages/9e/8d/ddbcf81ec751d8ee5fd18ac11ff38a0e110f39dfbf105e6d9db69d556dd0/google_auth-2.29.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for requests-oauthlib from https://files.pythonhosted.org/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for oauthlib>=3.2.2 from https://files.pythonhosted.org/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl.metadata
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\vkr20\program\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for coloredlogs from https://files.pythonhosted.org/packages/a7/06/3d6badcf13db419e25b07041d9c7b4a2c331d3f4e7134445ec5df57714cd/coloredlogs-15.0.1-py2.py3-none-any.whl.metadata
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\vkr20\program\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.7)
# Requirement already satisfied: protobuf in c:\users\vkr20\program\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\vkr20\program\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Obtaining dependency information for deprecated>=1.2.6 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.0.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Obtaining dependency information for googleapis-common-protos~=1.52 from https://files.pythonhosted.org/packages/dc/a6/12a0c976140511d8bc8a16ad15793b2aef29ac927baa0786ccb7ddbb6e1c/googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-common==1.24.0 from https://files.pythonhosted.org/packages/46/d3/b344cb181a525f7e4519c27de17d721c504e01063520b9003569ef9bf692/opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Obtaining dependency information for opentelemetry-proto==1.24.0 from https://files.pythonhosted.org/packages/14/b2/4e65d78d4b093f25fadeb215881ecbf5a77ee46a071f2b3a548ef724c728/opentelemetry_proto-1.24.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_proto-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-instrumentation-asgi==0.45b0 from https://files.pythonhosted.org/packages/21/c0/a50c91aad79ea205130d8d64426f7a36fefb806c5f5fdfdb51ea8cf67db1/opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-instrumentation==0.45b0 from https://files.pythonhosted.org/packages/fe/e5/cb0cfa596fa18d09f458058d6e55e2fc82300a45ae57c457c197949fd4a6/opentelemetry_instrumentation-0.45b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.45b0 from https://files.pythonhosted.org/packages/16/3a/d836ab98544e5618b397b4b2ea917f1b7699022c4a897cd850733df08112/opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-util-http==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-util-http==0.45b0 from https://files.pythonhosted.org/packages/13/e4/f62b2b098481c093d87095454360ab2dce1bc967c6220096e3d10207045a/opentelemetry_util_http-0.45b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for asgiref~=3.0 from https://files.pythonhosted.org/packages/39/e3/893e8757be2612e6c266d9bb58ad2e3651524b5b40cf56761e985a28b13e/asgiref-3.8.1-py3-none-any.whl.metadata
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Obtaining dependency information for monotonic>=1.5 from https://files.pythonhosted.org/packages/9a/67/7e8406a29b6c45be7af7740456f7f37025f0506ae2e05fb9009a53946860/monotonic-1.6-py2.py3-none-any.whl.metadata
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Obtaining dependency information for backoff>=1.10.0 from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vkr20\program\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vkr20\program\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\vkr20\program\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Obtaining dependency information for shellingham>=1.3.0 from https://files.pythonhosted.org/packages/e0/f9/0595336914c5619e5f28a1fb793285925a8cd4b432c9da0a987836c7f822/shellingham-1.5.4-py2.py3-none-any.whl.metadata
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (13.3.5)
# Requirement already satisfied: h11>=0.8 in c:\users\vkr20\program\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for httptools>=0.5.0 from https://files.pythonhosted.org/packages/14/e4/20d28dfe7f5b5603b6b04c33bb88662ad749de51f0c539a561f235f42666/httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\vkr20\program\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for watchfiles>=0.13 from https://files.pythonhosted.org/packages/f3/dc/2a8a447b783f5059c4bf7a6bad8fe59375a5a9ce872774763b25c21c2860/watchfiles-0.21.0-cp311-none-win_amd64.whl.metadata
#   Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for websockets>=10.4 from https://files.pythonhosted.org/packages/d1/40/6b169cd1957476374f51f4486a3e85003149e62a14e6b78a958c2222337a/websockets-12.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading websockets-12.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vkr20\program\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl.metadata
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\vkr20\program\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\vkr20\program\anaconda3\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\vkr20\program\anaconda3\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.5.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for humanfriendly>=9.1 from https://files.pythonhosted.org/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl.metadata
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\vkr20\program\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\vkr20\program\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for pyreadline3 from https://files.pythonhosted.org/packages/56/fc/a3c13ded7b3057680c8ae95a9b6cc83e63657c38e0005c400a5d018a33a7/pyreadline3-3.4.1-py3-none-any.whl.metadata
#   Downloading pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vkr20\program\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\vkr20\program\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#    ---------------------------------------- 0.0/525.5 kB ? eta -:--:--
#    ---------------- ----------------------- 215.0/525.5 kB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  522.2/525.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 525.5/525.5 kB 4.7 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.6 kB ? eta -:--:--
#    ---------------------------------------- 151.6/151.6 kB 8.8 MB/s eta 0:00:00
# Downloading bcrypt-4.1.2-cp39-abi3-win_amd64.whl (158 kB)
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ---------------------------------------- 158.3/158.3 kB 9.9 MB/s eta 0:00:00
# Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Downloading fastapi-0.110.2-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/91.9 kB ? eta -:--:--
#    ---------------------------------------- 91.9/91.9 kB 2.6 MB/s eta 0:00:00
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 16.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 9.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.5/1.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 7.8 MB/s eta 0:00:00
# Downloading mmh3-4.1.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading onnxruntime-1.17.3-cp311-cp311-win_amd64.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.6 MB 6.1 MB/s eta 0:00:01
#    --- ------------------------------------ 0.5/5.6 MB 6.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/5.6 MB 5.4 MB/s eta 0:00:01
#    ------ --------------------------------- 0.9/5.6 MB 5.1 MB/s eta 0:00:01
#    --------- ------------------------------ 1.3/5.6 MB 5.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.4/5.6 MB 5.4 MB/s eta 0:00:01
#    ------------ --------------------------- 1.7/5.6 MB 5.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.1/5.6 MB 5.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.6 MB 6.0 MB/s eta 0:00:01
#    ------------------- -------------------- 2.7/5.6 MB 5.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.3/5.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------- -------------- 3.6/5.6 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.1/5.6 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 4.4/5.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.9/5.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.6 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 6.8 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.1 kB ? eta -:--:--
#    ---------------------------------------- 60.1/60.1 kB ? eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.8 kB ? eta -:--:--
#    ---------------------------------------- 50.8/50.8 kB 2.5 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.1 kB ? eta -:--:--
#    ---------------------------------------- 106.1/106.1 kB 6.0 MB/s eta 0:00:00
# Downloading orjson-3.10.1-cp311-none-win_amd64.whl (139 kB)
#    ---------------------------------------- 0.0/139.1 kB ? eta -:--:--
#    ---------------------------------------- 139.1/139.1 kB 8.1 MB/s eta 0:00:00
# Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.3 kB ? eta -:--:--
#    ---------------------------------------- 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Downloading pulsar_client-3.5.0-cp311-cp311-win_amd64.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.3 MB 1.6 MB/s eta 0:00:03
#    ------- -------------------------------- 0.6/3.3 MB 6.1 MB/s eta 0:00:01
#    ------------- -------------------------- 1.1/3.3 MB 8.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.5/3.3 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.7/3.3 MB 7.3 MB/s eta 0:00:01
#    -------------------------- ------------- 2.2/3.3 MB 7.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.6/3.3 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 3.1/3.3 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  3.3/3.3 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 7.0 MB/s eta 0:00:00
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.2 kB ? eta -:--:--
#    ---------------------------------------- 47.2/47.2 kB ? eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
# Using cached googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
# Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl (55 kB)
#    ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#    ---------------------------------------- 55.4/55.4 kB ? eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 4.1 MB/s eta 0:00:00
# Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl (280 kB)
#    ---------------------------------------- 0.0/280.1 kB ? eta -:--:--
#    --------------------------------------- 280.1/280.1 kB 16.9 MB/s eta 0:00:00
# Downloading websockets-12.0-cp311-cp311-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    ---------------------------------------- 125.0/125.0 kB 3.7 MB/s eta 0:00:00
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53835 sha256=1ca5dc03436f6b1b8669c5a5d395f18223b2aa31f868a5d2d054fb3f2b7955cf
#   Stored in directory: c:\users\vkr20\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pyreadline3, pypika, monotonic, mmh3, websockets, tenacity, shellingham, rsa, pyproject_hooks, pulsar-client, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, importlib-resources, humanfriendly, httptools, googleapis-common-protos, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, google-auth, coloredlogs, build, typer, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.2 build-1.2.1 chroma-hnswlib-0.7.3 chromadb-0.4.24 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.2 google-auth-2.29.0 googleapis-common-protos-1.63.0 httptools-0.6.1 humanfriendly-10.0 importlib-resources-6.4.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.17.3 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-instrumentation-0.45b0 opentelemetry-instrumentation-asgi-0.45b0 opentelemetry-instrumentation-fastapi-0.45b0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 opentelemetry-util-http-0.45b0 orjson-3.10.1 posthog-3.5.0 pulsar-client-3.5.0 pypika-0.48.9 pyproject_hooks-1.0.0 pyreadline3-3.4.1 requests-oauthlib-2.0.0 rsa-4.9 shellingham-1.5.4 starlette-0.37.2 tenacity-8.2.3 typer-0.12.3 uvicorn-0.29.0 watchfiles-0.21.0 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import chromadb

# %%
merged_df
# Out:
#            num                                               name  \
# 0      9238535                the.boyfriend.school.(1990).eng.1cd
# 1      9238535                the.boyfriend.school.(1990).eng.1cd
# 2      9238535                the.boyfriend.school.(1990).eng.1cd
# 3      9238535                the.boyfriend.school.(1990).eng.1cd
# 4      9238535                the.boyfriend.school.(1990).eng.1cd
# ...        ...                                                ...
# 76031  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76032  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76033  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76034  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 76035  9207441  the.jeffersons.s06.e02.a.short.story.(1979).en...
#
#                                      file_content_chunks
# 0      advertise product brand herecontact www opensu...
# 1      oh please mean review mail get well card diary...
# 2      take quiet moment shall need see mr renault ri...
# 3      laugh mitchell wow never knew lizzie looked th...
# 4      skewed little bittoo heavily towards ginger mm...
# ...                                                  ...
# 76031  well movin movin east side movin deluxe apartm...
# 76032  sure havea special dessert two oh ice cream ch...
# 76033  yeah becausenobody else see u right uh gentlem...
# 76034  startedon speech ah hey fifthof scotch come oh...
# 76035  three george doe itlook like gettingthe hell g...
#
# [76036 rows x 3 columns]

# %%
merged_df['doc_vector_pretrained_bert'] = merged_df.file_content_chunks.progress_apply(model.encode)

merged_df.head()
# Out:
#  63%|█████████████████████████████████████████████▎                          | 47816/76036 [2:30:06<1:16:34,  6.14it/s]

# %%
merged_df.info()

# %%
User_query = pd.Series([input("Enter a user Query " )])

# %%
User_query.progress_apply(lambda x:  clean_content(x)) 

User_query.progress_apply(lambda x:  preprocess(x))

# %%
Query = User_query.progress_apply(model.encode)

# %%
Query[0]

# %%
cos_sim = util.cos_sim(Query, merged_df['doc_vector_pretrained_bert'])

# %%
a=cos_sim.argsort()[:][::].tolist()

# %%
single_list = []
for sublist in a:
    single_list.extend(sublist)

# %%
top_sub = merged_df.iloc[sublist[::-1]]

# %%
k=int(input(" No_of docs you want"))
top_sub[:k]

# %%
merged_df.to_csv("Sub_Titles_with_32.csv",index=False)
